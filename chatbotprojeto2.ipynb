# %%
import pyautogui
import time
import pyperclip


pyautogui.alert('O programa roda com configuração de tela 1366 x768')
pyautogui.press("winleft")
time.sleep(1)
pyautogui.write("Bloco de Notas")
time.sleep(1)
pyautogui.press("enter")
pyautogui.alert('Abra no um arquivo qualquer "txt" contido na pasta de resposta deste arquivo')
time.sleep(2)

pyautogui.press("winleft")
time.sleep(1)
pyautogui.write("Brave")
time.sleep(1)
pyautogui.press("enter")
time.sleep(5)
link= "https://web.whatsapp.com/"

pyperclip.copy(link)
pyautogui.hotkey("Ctrl","v")
pyautogui.press("enter")

time.sleep(10)
num =232
#msg fechada
tex='nada'
text2='Digite 0 para voltar'
text='nada'
while(text!='tchau1'):
    
    #enchendo a memoria com 'nada'
    pyperclip.copy(tex)
    # ultimo texto copiado
    #para click da escolha do usuario
    if(text=='nada'):
        num=num+72
        if(num==736):
            num=232
        pyautogui.click(x=86, y=num)
        time.sleep(1)
    else:
        pyautogui.click(x=86, y=232)
        time.sleep(1)
    #aceitar novos usuarios spam
    pyautogui.click(x=1058, y=623)
    #cancelar comentarios
    pyautogui.click(x=1335, y=639)
    pyautogui.click(x=1335, y=629)
    pyautogui.click(x=1335, y=619)
    time.sleep(1)
    #abrindo copiando e postando
    #ou acão fantasma de nada
    pyautogui.click(x=509, y=626 ,clicks=2)
    time.sleep(1)
    pyautogui.click(button='right')
    time.sleep(1)
    pyautogui.click(x=560, y=499)
    time.sleep(1)
    text = pyperclip.paste() 
    if(text!='nada'):
        try:
            procura=int(text)
            if(procura>8):
                procura=0
        except:
            procura=0
        i=0;
        #buncando a resposta no banco de dados
        
        pyautogui.click(x=908, y=746)
        pyautogui.hotkey("Ctrl","o")
        time.sleep(1)
        pyperclip.copy(procura)
        time.sleep(1)
        pyautogui.hotkey("Ctrl","v")
        time.sleep(1)
        pyautogui.write(".txt")
        time.sleep(1)
        pyautogui.press("enter")
        pyautogui.hotkey("Ctrl","a")
        pyautogui.hotkey("Ctrl","c")
        
        pyautogui.click(x=711, y=751)
        pyautogui.click(x=551, y=700)
        pyautogui.hotkey("Ctrl","v")
        pyautogui.press("enter")
        time.sleep(10)
